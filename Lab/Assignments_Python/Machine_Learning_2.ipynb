# %% [markdown]
# # Introduction to Data and Dataset
#
# ## What is Data
# Data Refers to individual facts,measurement or observations. Raw facts. We want to gain information from data.<br>
# <br>
# THIS IS WISDOM TREE <br>
# <br>
# GAINS SOME KIND OF EXPERIENCE <br>
# KNOWLEDGE <br>
# INFORMATION <br>
# DATA <br>
# <br>
# Writing data in form of rows and columns then it becomes dataset. <br>
# <br>
# Symmetric Binary : both outcomes are equally likely <br>
# Asymmetic Binary : both outcomes arent equally likely to occur...like original data medical data is sometimes biased ... i.e no wale jiyada hai <br>
# To deal with it, we do data augmentation and and new data generation we use synthetic method <br>
# <br>
# Qualitative ko convert into numerical data is called encoding <br>
# <br>
# In interval data, subtraction is meaningful and but if we take ratio its meaningless...for examples if today is 5 degree and yesterday it was 10 degree then we cant say that it is twice cooler today...we can say 5 degree cooler instead (temp in celcius)<br>
# In excel file, there is limitation since it can show limited rows and pura data isnt shown so we use csv file. <br>
# NoSQL is no structured database jismein we can store unstructured data like images,tweet<br>
# XML is exlerated markup language jismein user defined tags cam be used and we can use this for unstructurued data.<br>
# Email is semi structured data...where format of email hota hai but osmein content kya hoga voh unstructured hai.<br>

# %% [markdown]
# ## Pandas
#
# Dataframe : 2d array <br>
# Series : 1d array <br>
#
# Rows arent very often labelled since a dataset can have a lot of rows<br>
#
# Rows extracting:<br>
# loc : label based indexing...akhri position included...also column ka label dena hoga,not integers and for row u give number<br>
# iloc : integer location based indexing ....after ":" akhri position excluded <br>
# df.iloc[4] returns 5th row with all columns<br>
#
# In inequality operator, intermediate output comes i.e true false....boolean series <br>
# now we dont want this ans toh isko as index pass krenge inside df  <br>
# so do baar df aaya to gte final dataframe needed <br>
#
# DELETING COLUMN OR ROW <br>
# inplace:true means oski copy mein mein change ho rha hai <br>
# one function has multiple definations : polymorphism, overloading <br>
# labels, axis used when u wanna delete either row or column <br>
# therefore ek time par bas 3 cheeze pass kroge <br>
# index : row bta rhe, columns means columns bta rhe ho <br>

# %% [markdown]
# Assignment 1 mein 4th ques <br>
# we are converting image to texual image<br>
# Coloured Image has to be chnaged into numpy array for vextorized operations <br>
# image par operations krke ke liye we have to change to numpy array <br>
# now change it into text file because some file image formats dont work in other computers <br>
# readability better ho jayegi if we store it like this <br>
# image ko directly text file mein kyu nhi kiya ?? <br>
# because voh numerically save nhi krega and something non readable aa jayega...pixel ki values dikhni chahiye thi hamare acc toh isliye numpy arrray mein first converted and then text kyuki numpy array is human readable and pixels are freezed <br>
# IN CODE <br>
# 1st number in ppt....-1 means last dimension dedo i.e 3 in case of coloured image and 1 in case of gray scale...reshaping needed only in 3 channels because gray scale already in 2d <br>
# reshaped = ..... <br>
# toh 3 columns and number of rows apne hisaab se...har pixel like 0,255,255 and next pixel under it<br>
# PIL also import krna tha for this ques<br>

# %% [markdown]
# DATA PROCESSING <br>
# scaler = minmaxscalar() #making an object and passing nothing in constructor <br>
# fit means training <br>
# transform means changing yourself into value of x' <br>
# fit_tranform means dono cheeze ek saath ho rhi hai <br>
# discretization uses qcut in python <br>
# binirization mein dimensions increases and jitni elements hai utni columns ban jate hai <br>
# label encoding mein unwanted ordinal relationship means chahe ranking na ho but faltu ki sometimes we assume given 0,1 are ranking <br>
# correlation ranges from -1 to 1 <br>
# agar opp. direction mein do cheeze going with relation then -1 <br>
# no relation means zero <br>
# jaccard similarity mein 0,0 matched we dont count <br>
# to match text we split the text and split() brackets mein nothing means pure sentence ko space ke basis par split krdo <br>
# humne set mein convert kr diya because jaccard simillarity works only on set <br>
# cossine simillarity cant apply since categorical toh first used one hot encoding ans then found cossine simillarity <br>
# cosine similarity works on continuous data as welll as binary data <br>
# random_state means = 42 means har baar same random state hogi...do models ko do alag alag potion of data par train krke cant compare <br>
# also used cross validation <br>
# over fitting mein variance jiyada hai i.e har point ke acc we change the path in graph ...no error..bias is error ...galti ki no point <br>
# under fitting high bias kyuki galti ka hona jiyada change hai <br>
