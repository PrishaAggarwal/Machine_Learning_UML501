# %% [markdown]
# # Python : Introduction

# %% [markdown]
# Saturday Sunday assignment submission on github for machine learning

# %% [markdown]
# - .ipynb interactive python notebook
# - High level language
# - working closely with hardware is low level language
# - C, C++  were procedure based language...line write then execute...not learning from data...line by line execution...instructions
# - Python learns from data set and gets expirienced

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Flaws
# - Slow
# - Real life applications where things are live like playing games, python can be slow
# <br>
# - Compiler from high level languarge to machine learning...entire program at a time
# - after compling .obj file are made
# - interpretor is line by line execution...memory expensive...dynamic typing ke karan
# - here u have to mention what is data type
# - python is not expensive we dont have to decide data types...but ossi karan it is slow
# - jupyter notebook since we have raw text coding as well as writing text so
# - Julia, python, r...initially iske liye made to named jupyter...i.e ju pyt er
# - it has kernals...kernals is the one that helps various applications to run
# - python wale kernal par we run taki python ka syntax valid ho jaye

# %% [markdown]
# explicit typecasting when we do <br>
# implicit typecasting when khud se python mein ho jaye <br>

# %% [markdown]
# ques 1 : 6/2 = 3.0 <br>
# ques 2 : 6//2 = 3 (explicit int ans) <br>
# ques 3 : "hello"== "world" ans is false <br>
# ques 4 : 3.99 ans is 3...always a floor value <br>
# do while not present in python<br>
# switch case is also present<br>

# %% [markdown]
# ### Lists
#
# - multiple items in single variables
# - [ ]
# - mutable...i.e can be changed
# - indexing starst from 0
# - it is ordered...we can do indexing in this
# - allows duplicates
# - slicing is columns nikalna from dataset
# - dicing is rows nikalna from dataset
# - we can reverse

# %% [markdown]
# ### Tuple
#
# - ( )
# - im-mutuable
# - ordered

# %% [markdown]
# ### Set
#
# - unordered
# - unique elements
# - 1 to 3 and 3 to 1 are same sets since order se farak nhi padhta
# - chahe 10 times write 1 ...then it is counted only once
# - { }
# - set constuctor can also be used to make set...it is used to initialize a object (it is an instance of class)
# - class comes to life when new use krte hai...constructor use krke

# %%
c = set() #null set

# %%
c.add(3)
c.update([3,4,4])
c
# Out:
# {3, 4}

# %%
c.remove(3) #error if element not present in set
c.pop() # first element removed
c.discard(6) #element removed but if not present then bhi error nhi deta
c
# Out:
# set()

# %% [markdown]
# ### Union
#
# - 2 methods
# - pipelines
# - concatenioational (union)
# - for intersction use & or use the function

# %% [markdown]
# ### Frozen set
#
# - when we want something to be unique like roll number and shouldnt ne changed toh use this

# %% [markdown]
# ### Dictionary
#
# - here the indexing is done by key
# - ordered
# - { }
# - mutable

# %% [markdown]
# ### Strings
#
# - immutable
# - \+ for concatenation
# - *
# - find() to find a particular element in string

# %% [markdown]
# ### What is a model ?
#
# - mathematical equation
# - output is dependent on features
# - jiska coefficient jiyada oska jiyada reflect krega on output

# %% [markdown]
# ### Numpy : Numerical python
#
# - it allows for vectorized operations and fast
# - vectorized means what i studied in course
# - ek saath bulk data par same operation perform krna
# - GPU has more number of cores than CPU...CPU has 4-8 cores whereas GPU has lakhs of cores...basically cores is like multiple brains
# - deep learning GPU par hi only works
# - single insturctio multiple data par works numpy and GPU
# - arrays can be n dimentional; whheras matrices are only 2d matrices

# %% [markdown]
# - numpy array can be created from list or tuple
# - can we create numpy from dictionary and sets ?
# - (5,) means 5 elments in 1st dimension
# - ones and zeros work only with 1 d array and not with matrices
# - np.zeroes((5,5)) matruces of zeros and ones then we use tuples as input
# - indexing slicing both possible

# %% [markdown]
# array cannnot be changed...resize and value change not possible<br>
# make new array for new dimensions<br>

# %% [markdown]
# withput vextorized its in insufficient because if so many records to each time does so many things in backened like following
# - checking for every element i.e check data type of each element
# - high level abstractions..memory expensive since har cheez ke saath metadata hota
# - interpreted execution...line by line execution

# %% [markdown]
# during compile time in C , sab kuch till compile time hoga sab decide ho jayega like x ki jagah uski value place ho chuki hogi so it is fast whereas python without numpy is slow...numpy is faster and gives easy writing codes as in ppt<br>
# here vectorized krke python fast and then backend mein bhi vectorized operation hi hota hai so fast<br>
# backend par numpy has c backend isliye with numpy python gets fast
